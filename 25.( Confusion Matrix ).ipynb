# %% [markdown]
# <img src="attachment:e3662d0b-f20a-423f-8910-595717d24d6f.png" width="500" />

# %% [markdown]
# <img src="attachment:fbf50c9e-0dea-45a6-b2eb-92823903a1b0.png" width="500" />

# %% [markdown]
# <img src="attachment:a5f5d01f-b841-4e9d-a83c-a34efba2127e.png" width="500" />

# %% [markdown]
# <img src="attachment:e46b80a8-0b60-44b9-a9d8-a02eeb519448.jpg" width="250" />

# %% [markdown]
# <img src="attachment:c1e4e544-6fe4-4eb3-97d6-a5d1f74463e0.png" width="500" />

# %% [markdown]
# <img src="attachment:c313939a-c48c-42bf-8751-048b0a528f99.png" width="500" />

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\My\Downloads\placement (1).csv")
dataset.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %% [markdown]
# # Confusion Matrix Model

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
confusion_matrix(y_test,lr.predict(x_test))
# Out:
# array([[10,  0],
#        [ 0, 10]], dtype=int64)

# %%
cf = confusion_matrix(y_test,lr.predict(x_test))

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cf,annot=True)
plt.show()

# %% [markdown]
# ## Precision Score

# %%
precision_score(y_test,lr.predict(x_test))*100
# Out:
# 100.0

# %% [markdown]
# ## Recall Score

# %%
recall_score(y_test,lr.predict(x_test))*100
# Out:
# 100.0

# %% [markdown]
# ## f1_Score

# %%
f1_score(y_test,lr.predict(x_test))*100
# Out:
# 100.0
