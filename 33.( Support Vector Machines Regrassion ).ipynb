# %% [markdown]
# <img src="attachment:b6d437e7-da82-4a44-8f20-f28a1b6940df.webp" width="600" />

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# # For Linear Regression

# %%
dataset = pd.read_csv(r"C:\Users\My\Downloads\placement.csv")
dataset.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.show()

# %%
x = dataset[["cgpa"]]
y = dataset["package"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.svm import SVR

# %%
# Linear Model
sv = SVR (kernel="linear")
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 77.59775622669525

# %%
sv.score(x_train,y_train)*100
# Out:
# 77.370548592536

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.plot(dataset['cgpa'],sv.predict(x),color="red")
plt.show()

# %%
# poly Model
sv = SVR (kernel="poly",degree=3)
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
sv.score(x_test,y_test)*100
# Out:
# 73.97410826352183

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.scatter(dataset['cgpa'],sv.predict(x),color="red")
plt.show()

# %%
# rbf Model
sv = SVR (kernel="rbf",degree=3)
sv.fit(x_train,y_train)
# Out:
# SVR()

# %%
sv.score(x_test,y_test)*100
# Out:
# 76.48823445728577

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.scatter(dataset['cgpa'],sv.predict(x),color="red")
plt.show()

# %%
# sigmoid Model
sv = SVR (kernel="sigmoid",degree=3)
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='sigmoid')

# %%
sv.score(x_test,y_test)*100
# Out:
# -0.09180841401839057

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.scatter(dataset['cgpa'],sv.predict(x),color="red")
plt.show()

# %% [markdown]
# # For Polynomial Regression

# %%
dataset = pd.read_csv(r"D:\polynomial data.csv")
dataset.head()
# Out:
#    Level  Salary
# 0      1   45000
# 1      2   50000
# 2      3   60000
# 3      4   80000
# 4      5  110000

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Level",y="Salary",data=dataset)
plt.show()

# %%
dataset.shape
# Out:
# (100, 2)

# %%
x = dataset[['Level']] 
y = dataset['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.svm import SVR

# %%
# sigmoid Model
sv = SVR (kernel="sigmoid")
sv.fit(x_train, y_train)
# Out:
# SVR(kernel='sigmoid')

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Level",y="Salary",data=dataset)
plt.scatter(dataset['Level'],sv.predict(x),color="red")
plt.show()

# %%
# rbf Model
sv = SVR (kernel="rbf")
sv.fit(x_train, y_train)
# Out:
# SVR()

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Level",y="Salary",data=dataset)
plt.scatter(dataset['Level'],sv.predict(x),color="red")
plt.show()

# %%
# poly Model
sv = SVR (kernel="poly")
sv.fit(x_train, y_train)
# Out:
# SVR(kernel='poly')

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Level",y="Salary",data=dataset)
plt.scatter(dataset['Level'],sv.predict(x),color="red")
plt.show()

# %%
# linear Model
sv = SVR (kernel="linear")
sv.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Level",y="Salary",data=dataset)
plt.scatter(dataset['Level'],sv.predict(x),color="red")
plt.show()
